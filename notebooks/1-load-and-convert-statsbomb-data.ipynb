# %% [markdown]
# **Disclaimer**: this notebook's compatibility with StatsBomb event data 4.0.0 was last checked on December 30th, 2023.

# %%
import os
import warnings
import pandas as pd
pd.set_option('display.max_columns', None)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.filterwarnings(action="ignore", message="credentials were not supplied. open data access only")
import tqdm

# %%
# %load_ext autoreload
# %autoreload 2
from socceraction.data.statsbomb import StatsBombLoader
import socceraction.spadl as spadl

# %% [markdown]
# ## Set up the StatsBombLoader

# %%
# Use this if you want to use the free public statsbomb data
# or provide credentials to access the API
#SBL = StatsBombLoader(getter="remote", creds={"user": None, "passwd": None})

# # Uncomment the code below if you have a local folder on your computer with statsbomb data
datafolder = "data-fifa/spadl-statsbomb.h5" # Example of local folder with statsbomb data
SBL = StatsBombLoader(root=datafolder, getter="local")

# %%
# View all available competitions
competitions = SBL.competitions()
set(competitions.competition_name)
# Out:
# {'1. Bundesliga',
#  'African Cup of Nations',
#  'Champions League',
#  'Copa America',
#  'Copa del Rey',
#  "FA Women's Super League",
#  'FIFA U20 World Cup',
#  'FIFA World Cup',
#  'Indian Super league',
#  'La Liga',
#  'Liga Profesional',
#  'Ligue 1',
#  'Major League Soccer',
#  'NWSL',
#  'North American League',
#  'Premier League',
#  'Serie A',
#  'UEFA Euro',
#  'UEFA Europa League',
#  "UEFA Women's Euro",
#  "Women's World Cup"}

# %%
competitions[competitions['season_name'].str.contains('2023')]
# Out:
#     season_id  competition_id        competition_name  \
# 0         281               9           1. Bundesliga
# 2         107            1267  African Cup of Nations
# 58        235               7                 Ligue 1
# 61        107              44     Major League Soccer
# 72        107              72       Women's World Cup
#
#                 country_name competition_gender season_name
# 0                    Germany               male   2023/2024
# 2                     Africa               male        2023
# 58                    France               male   2022/2023
# 61  United States of America               male        2023
# 72             International             female        2023

# %%
# Fifa world cup
selected_competitions = competitions[
    (competitions.competition_name == "FIFA World Cup")
    & (competitions.season_name == "2018")
]

# # Messi data
# selected_competitions = competitions[competitions.competition_name == "La Liga"]

# # FA Women's Super League
# selected_competitions = competitions[competitions.competition_name == "FA Women's Super League"]

selected_competitions
# Out:
#     season_id  competition_id competition_name   country_name  \
# 30          3              43   FIFA World Cup  International
#
#    competition_gender season_name
# 30               male        2018

# %%
# Get games from all selected competitions
games = pd.concat([
    SBL.games(row.competition_id, row.season_id)
    for row in selected_competitions.itertuples()
])
games[["home_team_id", "away_team_id", "game_date", "home_score", "away_score"]]
# Out:
#     home_team_id  away_team_id           game_date  home_score  away_score
# 0            769           768 2018-07-03 20:00:00           1           1
# 1            768           782 2018-06-28 20:00:00           0           1
# 2            790           773 2018-07-03 16:00:00           1           0
# 3            797           780 2018-06-25 20:00:00           1           1
# 4            780           788 2018-06-20 14:00:00           1           0
# ..           ...           ...                 ...         ...         ...
# 59           796           774 2018-06-19 20:00:00           3           1
# 60           796           785 2018-07-07 20:00:00           2           2
# 61           776           771 2018-06-26 16:00:00           0           0
# 62           778           787 2018-06-24 17:00:00           2           2
# 63           799           774 2018-06-25 16:00:00           2           1
#
# [64 rows x 5 columns]

# %% [markdown]
# ## Load and convert match data

# %%
games_verbose = tqdm.tqdm(list(games.itertuples()), desc="Loading game data")
teams, players = [], []
actions = {}
for game in games_verbose:
    # load data
    teams.append(SBL.teams(game.game_id))
    players.append(SBL.players(game.game_id))
    events = SBL.events(game.game_id)
    # convert data
    actions[game.game_id] = spadl.statsbomb.convert_to_actions(
        events, 
        home_team_id=game.home_team_id,
        xy_fidelity_version=1,
        shot_fidelity_version=1
    )

teams = pd.concat(teams).drop_duplicates(subset="team_id")
players = pd.concat(players)
# Out:
# Loading game data:   0%|          | 0/64 [00:00<?, ?it/s]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   2%|▏         | 1/64 [00:01<01:11,  1.13s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   3%|▎         | 2/64 [00:02<01:09,  1.12s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   5%|▍         | 3/64 [00:03<01:03,  1.04s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   6%|▋         | 4/64 [00:12<04:06,  4.11s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   8%|▊         | 5/64 [00:13<02:59,  3.04s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   9%|▉         | 6/64 [00:14<02:23,  2.48s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  11%|█         | 7/64 [00:15<01:55,  2.03s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  12%|█▎        | 8/64 [00:16<01:37,  1.74s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  14%|█▍        | 9/64 [00:17<01:21,  1.47s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  16%|█▌        | 10/64 [00:18<01:13,  1.36s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  17%|█▋        | 11/64 [00:19<01:06,  1.25s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  19%|█▉        | 12/64 [00:20<01:03,  1.23s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  20%|██        | 13/64 [00:21<00:57,  1.14s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  22%|██▏       | 14/64 [00:22<00:55,  1.11s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  23%|██▎       | 15/64 [00:23<00:53,  1.08s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  25%|██▌       | 16/64 [00:25<00:52,  1.09s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  27%|██▋       | 17/64 [00:26<00:49,  1.06s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  28%|██▊       | 18/64 [00:27<00:48,  1.06s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# ...
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  91%|█████████ | 58/64 [01:08<00:06,  1.01s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  92%|█████████▏| 59/64 [01:10<00:05,  1.07s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  94%|█████████▍| 60/64 [01:11<00:04,  1.02s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  95%|█████████▌| 61/64 [01:12<00:03,  1.04s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  97%|█████████▋| 62/64 [01:13<00:02,  1.03s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  98%|█████████▊| 63/64 [01:14<00:01,  1.02s/it]/Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/data/statsbomb/loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# /Users/raghav/.pyenv/versions/3.11.4/envs/soccer/lib/python3.11/site-packages/socceraction/spadl/statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data: 100%|██████████| 64/64 [01:15<00:00,  1.18s/it]

# %%
events
# Out:
#       game_id                              event_id  period_id  team_id  \
# 0        7559  46b33c8d-8e83-4d1e-8549-acdb30daf2f0          1      799
# 1        7559  5a23945a-c063-4fa9-88b9-aae9b330fc7a          1      774
# 2        7559  308ed484-e69c-47a9-8187-ff2cbaab23f4          1      774
# 3        7559  c70095f4-cbf1-4c44-88be-fb260f405631          1      799
# 4        7559  49d14d7d-f30d-4cc9-9782-a961b11cd858          1      774
# ...       ...                                   ...        ...      ...
# 3826     7559  84855116-f3ee-4671-b757-b9ce80d79008          2      799
# 3827     7559  2418f991-1467-4599-a115-8b8c8927c5c6          2      774
# 3828     7559  d0237cd7-d111-411a-a75d-e7f2dfd560aa          2      774
# 3829     7559  02496cdc-24e5-48e6-a9bc-10e598064edc          2      774
# 3830     7559  ea485df9-9d5c-455f-b8ba-48523de17a89          2      799
#
#       player_id  type_id    type_name  index              timestamp  minute  \
# 0           NaN       35  Starting XI      1        0 days 00:00:00       0
# 1           NaN       35  Starting XI      2        0 days 00:00:00       0
# 2           NaN       18   Half Start      3        0 days 00:00:00       0
# 3           NaN       18   Half Start      4        0 days 00:00:00       0
# 4        5252.0       30         Pass      5 0 days 00:00:00.100000       0
# ...         ...      ...          ...    ...                    ...     ...
# 3826     5187.0       16         Shot   3827 0 days 00:49:05.160000      94
# 3827     6292.0       23  Goal Keeper   3828 0 days 00:49:06.053000      94
# 3828     3531.0       30         Pass   3829 0 days 00:50:28.920000      95
# 3829        NaN       34     Half End   3830 0 days 00:50:33.160000      95
# 3830        NaN       34     Half End   3831 0 days 00:50:33.160000      95
#
#       second  possession  possession_team_id possession_team_name  \
# 0          0           1                 799         Saudi Arabia
# 1          0           1                 799         Saudi Arabia
# 2          0           1                 799         Saudi Arabia
# 3          0           1                 799         Saudi Arabia
# 4          0           2                 774                Egypt
# ...      ...         ...                 ...                  ...
# 3826       5         158                 799         Saudi Arabia
# 3827       6         158                 799         Saudi Arabia
# 3828      28         159                 774                Egypt
# 3829      33         159                 774                Egypt
# 3830      33         159                 774                Egypt
#
#       play_pattern_id play_pattern_name     team_name  duration  \
# 0                   1      Regular Play  Saudi Arabia     0.000
# 1                   1      Regular Play         Egypt     0.000
# 2                   1      Regular Play         Egypt     9.053
# 3                   1      Regular Play  Saudi Arabia     8.920
# 4                   9     From Kick Off         Egypt     0.933
# ...               ...               ...           ...       ...
# 3826                1      Regular Play  Saudi Arabia     0.893
# 3827                1      Regular Play         Egypt       NaN
# 3828                9     From Kick Off         Egypt     0.933
# 3829                9     From Kick Off         Egypt       NaN
# 3830                9     From Kick Off  Saudi Arabia       NaN
#
#                                                   extra  \
# 0     {'tactics': {'formation': 4141, 'lineup': [{'p...
# 1     {'tactics': {'formation': 4231, 'lineup': [{'p...
# 2                                                    {}
# 3                                                    {}
# 4     {'pass': {'recipient': {'id': 3568, 'name': 'M...
# ...                                                 ...
# 3826  {'shot': {'statsbomb_xg': 0.021029433, 'end_lo...
# 3827  {'goalkeeper': {'position': {'id': 44, 'name':...
# 3828  {'pass': {'recipient': {'id': 5262, 'name': 'T...
# 3829                                                 {}
# 3830                                                 {}
#
#                               related_events                   player_name  \
# 0                                         []                           NaN
# 1                                         []                           NaN
# 2     [c70095f4-cbf1-4c44-88be-fb260f405631]                           NaN
# 3     [308ed484-e69c-47a9-8187-ff2cbaab23f4]                           NaN
# 4     [2fd09a99-c322-46e8-a957-4205530ed4c0]                 Marwan Mohsen
# ...                                      ...                           ...
# 3826  [2418f991-1467-4599-a115-8b8c8927c5c6]     Salem Mohammed Al Dawsari
# 3827  [84855116-f3ee-4671-b757-b9ce80d79008]  Essam Kamal Tawfik El Hadary
# 3828                                      []                 Mohamed Salah
# 3829  [ea485df9-9d5c-455f-b8ba-48523de17a89]                           NaN
# 3830  [02496cdc-24e5-48e6-a9bc-10e598064edc]                           NaN
#
#       position_id              position_name       location  under_pressure  \
# 0             NaN                        NaN            NaN           False
# 1             NaN                        NaN            NaN           False
# 2             NaN                        NaN            NaN           False
# 3             NaN                        NaN            NaN           False
# 4            23.0             Center Forward   [60.0, 40.0]           False
# ...           ...                        ...            ...             ...
# 3826         19.0  Center Attacking Midfield  [116.0, 53.0]           False
# 3827          1.0                 Goalkeeper    [1.0, 36.0]           False
# 3828         22.0       Right Center Forward   [61.0, 41.0]           False
# 3829          NaN                        NaN            NaN           False
# 3830          NaN                        NaN            NaN           False
#
#       counterpress
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 3826         False
# 3827         False
# 3828         False
# 3829         False
# 3830         False
#
# [3831 rows x 26 columns]

# %% [markdown]
# ## Store converted spadl data in a h5-file

# %%
datafolder = "../data-fifa"

# Create data folder if it doesn't exist
if not os.path.exists(datafolder):
    os.mkdir(datafolder)
    print(f"Directory {datafolder} created.")

spadl_h5 = os.path.join(datafolder, "spadl-statsbomb.h5")

# Store all spadl data in h5-file
with pd.HDFStore(spadl_h5) as spadlstore:
    spadlstore["competitions"] = selected_competitions
    spadlstore["games"] = games
    spadlstore["teams"] = teams
    spadlstore["players"] = players[['player_id', 'player_name', 'nickname']].drop_duplicates(subset='player_id')
    spadlstore["player_games"] = players[['player_id', 'game_id', 'team_id', 'is_starter', 'starting_position_id', 'starting_position_name', 'minutes_played']]
    for game_id in actions.keys():
        spadlstore[f"actions/game_{game_id}"] = actions[game_id]

# %% [markdown]
# ## Plot the spadl data
# Extra library required: ```pip install matplotsoccer```

# %%
with pd.HDFStore(spadl_h5) as spadlstore:
    games = (
        spadlstore["games"]
        .merge(spadlstore["competitions"], how='left')
        .merge(spadlstore["teams"].add_prefix('home_'), how='left')
        .merge(spadlstore["teams"].add_prefix('away_'), how='left'))
    # Select England vs Belgium game at World Cup
    game = games[(games.competition_name == "FIFA World Cup") 
                  & (games.away_team_name == "England")
                  & (games.home_team_name == "Belgium")]
    game_id = game.game_id.values[0]
    actions = (
        spadlstore[f"actions/game_{game_id}"]
        .merge(spadl.actiontypes_df(), how="left")
        .merge(spadl.results_df(), how="left")
        .merge(spadl.bodyparts_df(), how="left")
        .merge(spadlstore["players"], how="left")
        .merge(spadlstore["teams"], how="left")
    )

# use nickname if available else use full name
actions["player_name"] = actions[["nickname", "player_name"]].apply(lambda x: x.iloc[0] if x.iloc[0] else x.iloc[1], axis=1)
del actions['nickname']
actions[:5]
# Out:
#    game_id                     original_event_id  period_id  time_seconds  \
# 0     8657  84438495-6341-4eba-bf90-82db1f6703fb          1         0.533
# 1     8657  6f02abb4-0b81-4531-be11-6bf6ea7e695b          1         1.252
# 2     8657  34b355a6-8b5f-4954-8dfd-fcc77df5c40c          1         2.133
# 3     8657  29b70f75-5970-491c-acc7-5dbfb353200c          1         3.732
# 4     8657  8fd1ffd0-b984-4823-ab2c-f249c04adc12          1         4.933
#
#    team_id  player_id  start_x  start_y    end_x   end_y  type_id  result_id  \
# 0      782     3289.0  52.9375   33.575  44.1875  33.575        0          1
# 1      782     5642.0  44.1875   33.575  44.1875  34.425       21          1
# 2      782     5642.0  44.1875   34.425  31.9375  53.125        0          1
# 3      782     3077.0  31.9375   53.125  28.4375  53.125       21          1
# 4      782     3077.0  28.4375   53.125  24.0625  38.675        0          1
#
#    bodypart_id  action_id type_name result_name bodypart_name     player_name  \
# 0            5          0      pass     success    foot_right   Romelu Lukaku
# 1            0          1   dribble     success          foot     Axel Witsel
# 2            5          2      pass     success    foot_right     Axel Witsel
# 3            0          3   dribble     success          foot  Jan Vertonghen
# 4            4          4      pass     success     foot_left  Jan Vertonghen
#
#   team_name
# 0   Belgium
# 1   Belgium
# 2   Belgium
# 3   Belgium
# 4   Belgium

# %%
actions.columns
# Out:
# Index(['game_id', 'original_event_id', 'period_id', 'time_seconds', 'team_id',
#        'player_id', 'start_x', 'start_y', 'end_x', 'end_y', 'type_id',
#        'result_id', 'bodypart_id', 'action_id', 'type_name', 'result_name',
#        'bodypart_name', 'player_name', 'team_name'],
#       dtype='object')

# %%
import matplotsoccer

# Select the 5 actions preceding the 2-0
shot = 2201
a = actions[shot-4:shot+1].copy()

# Print the game date and timestamp of the goal
g = game.iloc[0]
minute = int((a.period_id.values[0]-1) * 45 + a.time_seconds.values[0] // 60)
game_info = f"{g.game_date} {g.home_team_name} {g.home_score}-{g.away_score} {g.away_team_name} {minute + 1}'"
print(game_info)

# Plot the actions
def nice_time(row):
    minute = int((row.period_id-1)*45 +row.time_seconds // 60)
    second = int(row.time_seconds % 60)
    return f"{minute}m{second}s"

a["nice_time"] = a.apply(nice_time, axis=1)
labels = a[["nice_time", "type_name", "player_name", "team_name"]]

ax = matplotsoccer.actions(
    location=a[["start_x", "start_y", "end_x", "end_y"]],
    action_type=a.type_name,
    team= a.team_name,
    result= a.result_name == "success",
    label=labels,
    labeltitle=["time", "actiontype", "player", "team"],
    zoom=False,
    figsize=6
)
# Out:
# 2018-07-14 16:00:00 Belgium 2-0 England 82'
